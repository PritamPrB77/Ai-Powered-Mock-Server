# %%
import requests

OLLAMA_URL = "http://localhost:11434/api/generate"
MODEL_NAME = "mistral"   # Change to "qwen2.5:3b" if you prefer

def chat_with_ollama(prompt):
    payload = {
        "model": MODEL_NAME,
        "prompt": prompt,
        "temperature": 0.2,
        "stream": False
    }

    try:
        response = requests.post(OLLAMA_URL, json=payload)
        response.raise_for_status()
        return response.json()["response"]
    except Exception as e:
        return f"Error: {e}"

if __name__ == "__main__":
    print("Local Ollama Chat (type 'exit' to quit)\n")

    while True:
        user_input = input("You: ")

        if user_input.lower() in ["exit", "quit"]:
            print("Exiting...")
            break

        reply = chat_with_ollama(user_input)
        print("\nAI:", reply)
# Out:
# Local Ollama Chat (type 'exit' to quit)

# %%
import requests

OLLAMA_URL = "http://localhost:11434/api/generate"
# MODEL_NAME = "qwen2.5:3b"
MODEL_NAME = "mistral"

def generate_once(prompt):
    payload = {
        "model": MODEL_NAME,
        "prompt": prompt,
        "temperature": 0.2,
       "num_predict": 60,
        "top_k": 20,
         "top_p": 0.9,
        "stream": False
    }

    response = requests.post(OLLAMA_URL, json=payload)
    return response.json()["response"]

if __name__ == "__main__":
    user_prompt = input("Enter your prompt: ")
    result = generate_once(user_prompt)
    print("\nModel Output:\n")
    print(result)
# Out:
# Model Output:
#
#  Odisha, formerly known as Orissa, is one of the eastern states in India, situated on the eastern coast between latitudes 16°45' and 23°06'N and longitudes 82°37' and 87°24'E. The state shares its boundaries with West Bengal to the northeast, Jharkhand to the north, Chhattisgarh to the west, Andhra Pradesh to the south and Bay of Bengal to the east.
#
# Odisha is rich in cultural heritage, with temples like Konark Sun Temple, Lingaraj Temple, and Jagannath Puri Temple being UNESCO World Heritage Sites. The capital city of Odisha is Bhubaneswar, which is a major tourist destination due to its ancient temples and modern infrastructure.
#
# The state is known for its biodiversity with various national parks and wildlife sanctuaries like Simlipal National Park, Bhitarkanika Mangrove Forest, and Dhenkanal Wildlife Sanctuary. The economy of Odisha is mainly based on agriculture, industries, and tourism.
#
# Odia language, also known as Oriya, is the official and primary language of the state. The people of Odisha are known for their warm hospitality and rich cultural traditions. Some popular festivals celebrated in Odisha include Dussehra (Durga Puja), Diwali, Makar Sankranti, Raja Parba, and Chau Dance Festival.
#
# Odisha has a rich history dating back to the Indus Valley Civilization, with many ancient cities and monuments scattered throughout the state. The Kalinga Empire, which was founded by King Kharavela in the 2nd century BC, is one of the most significant historical empires in Odisha.
#
# The state has a diverse culture with various tribes living in its forests and hills, including Saora, Kondh, Dongaria Kondh, Bonda, Joharas, Lodhas, Munda, Gonds, Malto, and Paroja. The state government takes several initiatives to preserve the cultural and traditional values of these tribal communities.
